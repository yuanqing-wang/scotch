# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as plticker
import pandas as pd

# %%
interval = [64,128, 256, 512]
negs_rff_nonnormalize = [211889313, 212831839,  212656936, 212513185]
ang_hyb_att_nonnormalize = [125652463, 130217538, 125540229, 129610217]
ang_gau_att_nonnormalize = [127416067, 131112075, 130053172, 124356581]

# %%
f=pd.DataFrame({"negs_rff_nonnormalize":negs_rff_nonnormalize ,"ang_hyb_att_nonnormalize":ang_hyb_att_nonnormalize,"ang_gau_att_nonnormalize":ang_gau_att_nonnormalize,"interval":interval})

# %%
fig = f.plot(kind='line', x="interval", y=["negs_rff_nonnormalize", "ang_hyb_att_nonnormalize",
                                          "ang_gau_att_nonnormalize"],figsize=(14,8),lw=2.5,grid=False)
ax.plot()
loc = plticker.MultipleLocator(base=20.0) # this locator puts ticks at regular intervals
loc2 = plticker.MultipleLocator(base=10000000.0)
ax.set_ylim(1.0e8, 2.35e8)
ax.set_ylabel('Y_LABEL',fontsize=18)
ax.set_xlabel('X_LABEL',fontsize=18)
ax.xaxis.set_major_locator(loc)
ax.yaxis.set_major_locator(loc2)
fig.savefig('Subplot_ex3.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/sd/1vc_q83x5rn9jjrd0x47_cc00000gn/T/ipykernel_26062/1152399004.py in <module>
#       9 ax.xaxis.set_major_locator(loc)
#      10 ax.yaxis.set_major_locator(loc2)
# ---> 11 fig.savefig('Subplot_ex3.png')
#
# AttributeError: 'AxesSubplot' object has no attribute 'savefig'

# %%
plotdata = pd.DataFrame({
    "pies_2018":[40, 12, 10, 26, 36],
    "pies_2019":[19, 8, 30, 21, 38],
    "pies_2020":[10, 10, 42, 17, 37]
    }, 
    index=["Dad", "Mam", "Bro", "Sis", "Me"]
)
plotdata.plot(kind="bar")
plt.title("Mince Pie Consumption Study")
plt.xlabel("Family Member")
plt.ylabel("Pies Consumed")
# Out:
# Text(0, 0.5, 'Pies Consumed')
