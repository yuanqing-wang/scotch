# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
plt.style.use('seaborn')

# %%
gw = pd.read_csv("data/Global_Mean_Estimates_based_on_Land_and_Ocean_Data.csv",index_col=False)
gw.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Temp', 'Smoothed'], dtype='object')

# %%
gw= gw.drop(columns=["Unnamed: 0"])

# %%
gw
# Out:
#      Year  Temp  Smoothed
# 0    1880 -0.15     -0.08
# 1    1881 -0.07     -0.12
# 2    1882 -0.10     -0.15
# 3    1883 -0.17     -0.19
# 4    1884 -0.27     -0.23
# ..    ...   ...       ...
# 136  2016  1.02      0.88
# 137  2017  0.92      0.91
# 138  2018  0.85      0.95
# 139  2019  0.98      0.98
# 140  2020  1.02      1.01
#
# [141 rows x 3 columns]

# %%
gw.plot(x='Year',figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
ax=gw.plot(x='Year',y='Smoothed')
gw.plot.scatter(x='Year',y='Temp',c='Temp', colormap='inferno',figsize=(20,5),ax=ax)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Temp'>

# %%
gw2=gw.drop(columns='Temp')
gw3=gw.drop(columns='Smoothed')
gw2
# Out:
#      Year  Smoothed
# 0    1880     -0.08
# 1    1881     -0.12
# 2    1882     -0.15
# 3    1883     -0.19
# 4    1884     -0.23
# ..    ...       ...
# 136  2016      0.88
# 137  2017      0.91
# 138  2018      0.95
# 139  2019      0.98
# 140  2020      1.01
#
# [141 rows x 2 columns]

# %%
gw2=gw2.set_index('Year')
sns.set(rc={'figure.figsize':(20,5)})
sns.heatmap(gw2.T)
gw2
# Out:
#       Smoothed
# Year
# 1880     -0.08
# 1881     -0.12
# 1882     -0.15
# 1883     -0.19
# 1884     -0.23
# ...        ...
# 2016      0.88
# 2017      0.91
# 2018      0.95
# 2019      0.98
# 2020      1.01
#
# [141 rows x 1 columns]

# %%
gw3=gw3.set_index('Year')
sns.set(rc={'figure.figsize':(20,5)})
sns.heatmap(gw3.T)
gw3
# Out:
#       Temp
# Year
# 1880 -0.15
# 1881 -0.07
# 1882 -0.10
# 1883 -0.17
# 1884 -0.27
# ...    ...
# 2016  1.02
# 2017  0.92
# 2018  0.85
# 2019  0.98
# 2020  1.02
#
# [141 rows x 1 columns]

# %%
gwdec = pd.read_csv("data/tempbydecade.csv")
gwdec=gwdec.set_index('Year')
gwdec
# Out:
#        1880   1890   1900   1910   1920   1930   1940   1950   1960   1970  \
# Year
# 0     -0.16  -0.35  -0.08  -0.43  -0.28  -0.16   0.13  -0.17  -0.03   0.03
# 1     -0.08  -0.22  -0.16  -0.44  -0.19  -0.09   0.19  -0.07   0.06  -0.08
# 2     -0.10  -0.27  -0.28  -0.36  -0.29  -0.16   0.07   0.01   0.03   0.01
# 3     -0.17  -0.31  -0.37  -0.34  -0.27  -0.28   0.09   0.08   0.05   0.16
# 4     -0.28  -0.30  -0.47  -0.15  -0.27  -0.12   0.20  -0.13  -0.20  -0.07
# 5     -0.33  -0.23  -0.27  -0.14  -0.22  -0.20   0.09  -0.14  -0.11  -0.01
# 6     -0.31  -0.11  -0.23  -0.36  -0.11  -0.15  -0.07  -0.19  -0.06  -0.10
# 7     -0.36  -0.11  -0.39  -0.46  -0.22  -0.03  -0.03   0.05  -0.02   0.18
# 8     -0.17  -0.27  -0.43  -0.30  -0.20   0.00  -0.11   0.06  -0.08   0.07
# 9     -0.11  -0.18  -0.48  -0.28  -0.36  -0.01  -0.11   0.03   0.05   0.16
#
#        1980   1990   2000   2010   2020
# Year
# 0      0.26   0.45   0.39   0.72   1.02
# 1      0.32   0.40   0.54   0.61    NaN
# ...

# %%
sns.set(rc={'figure.figsize':(20,5)})
sns.heatmap(gwdec)
# Out:
# <AxesSubplot:ylabel='Year'>

# %%
gw4=gw3.sort_values('Temp',ascending=False)
sns.set(rc={'figure.figsize':(5,30)})
sns.heatmap(gw4)
gw4[:20]
# Out:
#       Temp
# Year
# 2020  1.02
# 2016  1.02
# 2019  0.98
# 2017  0.92
# 2015  0.90
# 2018  0.85
# 2014  0.75
# 2010  0.72
# 2013  0.68
# 2005  0.68
# 2007  0.67
# 2009  0.66
# 2012  0.65
# 2006  0.64
# 2002  0.63
# 2003  0.62
# 2011  0.61
# 1998  0.61
# 2001  0.54
# 2004  0.54

# %%
gw4=gw3.sort_values('Temp',ascending=False)
sns.set(rc={'figure.figsize':(5,5)})
sns.heatmap(gw4[:20])
# Out:
# <AxesSubplot:ylabel='Year'>

# %%
sns.heatmap(gw4)
# Out:
# <AxesSubplot:ylabel='Year'>
