# %%
import d3fdgraph
import pandas as pd
df = pd.DataFrame(
    [{"source": "electromagnetism", "target": "statistical-mech", "weight": 1},
     {"source": "electromagnetism", "target": "quantum-mech", "weight": 2},
     {"source": "statistical-mech", "target": "quantum-mech", "weight":3},
     {"source": "quantum-mech", "target": "classical-dynamics", "weight":3},
     {"source": "classical-dynamics", "target": "optical-physics", "weight":3},
     {"source": "particle-physics", "target": "nuclear-physics", "weight":3}
    ])

# %%
d3fdgraph.plot_force_directed_graph(df)
# Out:
# <script src="/static/components/requirejs/require.js"></script>
# <div id="d3-container-2170029"></div>
# <div>force-directed graph</div>
#
# <style>
#     .links line {
#         stroke: #88d;
#         stroke-opacity: .2;
#     }
#     .nodes circle {
#         pointer-events: all;
#         stroke: #fff;
#         fill: #a55;
#         stroke-width: 1.5px;
#         opacity: 0.7;
#     }
#     .nodes text {
#         pointer-events: none;
#         font: 10px sans-serif;
#         fill: #333;
#         opacity: .5;
#     }
# </style>
